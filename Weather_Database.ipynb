# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=762a774f9c2e4adcbd757e05d242ce96

# %%
lats = np.random.uniform(-90.000, 90.000, size = 2000)
lngs = np.random.uniform(-180.000, 180.000, size = 2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 775

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | cherskiy
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | lebu
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | carnarvon
# Processing Record 7 of Set 1 | qaanaaq
# Processing Record 8 of Set 1 | auki
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 1 | lavrentiya
# Processing Record 12 of Set 1 | novobirilyussy
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | port augusta
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | old road
# City not found. Skipping...
# Processing Record 18 of Set 1 | chokurdakh
# Processing Record 19 of Set 1 | mahibadhoo
# Processing Record 20 of Set 1 | berlevag
# Processing Record 21 of Set 1 | nueve de julio
# Processing Record 22 of Set 1 | mahebourg
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | ipixuna
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | soe
# Processing Record 29 of Set 1 | cayenne
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | ancud
# Processing Record 32 of Set 1 | lensk
# Processing Record 33 of Set 1 | trairi
# Processing Record 34 of Set 1 | nuevo progreso
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | castro
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | fornosovo
# Processing Record 39 of Set 1 | hamadan
# Processing Record 40 of Set 1 | swan hill
# Processing Record 41 of Set 1 | atbasar
# Processing Record 42 of Set 1 | kieta
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | sioux lookout
# Processing Record 45 of Set 1 | talara
# Processing Record 46 of Set 1 | saint-leu
# Processing Record 47 of Set 1 | tuburan
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | ballina
# Processing Record 50 of Set 1 | giubiasco
# Processing Record 1 of Set 2 | kahului
# Processing Record 2 of Set 2 | sulurpeta
# City not found. Skipping...
# Processing Record 3 of Set 2 | aswan
# Processing Record 4 of Set 2 | chuy
# Processing Record 5 of Set 2 | codrington
# Processing Record 6 of Set 2 | nouadhibou
# Processing Record 7 of Set 2 | esperance
# Processing Record 8 of Set 2 | rafraf
# Processing Record 9 of Set 2 | matara
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | saint-philippe
# Processing Record 12 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 2 | kaitangata
# Processing Record 14 of Set 2 | mango
# Processing Record 15 of Set 2 | leningradskiy
# Processing Record 16 of Set 2 | caravelas
# Processing Record 17 of Set 2 | ligayan
# Processing Record 18 of Set 2 | yulara
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | zatoka
# Processing Record 21 of Set 2 | klaksvik
# Processing Record 22 of Set 2 | airai
# Processing Record 23 of Set 2 | shingu
# Processing Record 24 of Set 2 | souillac
# Processing Record 25 of Set 2 | cidreira
# Processing Record 26 of Set 2 | pisco
# Processing Record 27 of Set 2 | beringovskiy
# Processing Record 28 of Set 2 | ust-nera
# Processing Record 29 of Set 2 | ust-maya
# Processing Record 30 of Set 2 | new norfolk
# Processing Record 31 of Set 2 | port alfred
# Processing Record 32 of Set 2 | iisalmi
# Processing Record 33 of Set 2 | palembang
# Processing Record 34 of Set 2 | portree
# Processing Record 35 of Set 2 | tasiilaq
# Processing Record 36 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 2 | muravlenko
# Processing Record 38 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 2 | mayo
# Processing Record 40 of Set 2 | ranong
# Processing Record 41 of Set 2 | mataura
# Processing Record 42 of Set 2 | pedernales
# Processing Record 43 of Set 2 | port elizabeth
# Processing Record 44 of Set 2 | verkhnyaya inta
# Processing Record 45 of Set 2 | cairns
# Processing Record 46 of Set 2 | tual
# Processing Record 47 of Set 2 | nizhnekamsk
# Processing Record 48 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 2 | najran
# Processing Record 50 of Set 2 | vardo
# Processing Record 1 of Set 3 | vila velha
# Processing Record 2 of Set 3 | champerico
# Processing Record 3 of Set 3 | padang
# Processing Record 4 of Set 3 | dese
# Processing Record 5 of Set 3 | praia
# Processing Record 6 of Set 3 | sorland
# Processing Record 7 of Set 3 | naze
# Processing Record 8 of Set 3 | kulhudhuffushi
# Processing Record 9 of Set 3 | natal
# Processing Record 10 of Set 3 | hilo
# Processing Record 11 of Set 3 | omboue
# Processing Record 12 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 3 | vagur
# Processing Record 14 of Set 3 | bethel
# Processing Record 15 of Set 3 | vilhena
# Processing Record 16 of Set 3 | yellowknife
# Processing Record 17 of Set 3 | puerto ayora
# Processing Record 18 of Set 3 | eyrarbakki
# Processing Record 19 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 3 | nikolskoye
# Processing Record 21 of Set 3 | iqaluit
# Processing Record 22 of Set 3 | diamantino
# Processing Record 23 of Set 3 | saskylakh
# Processing Record 24 of Set 3 | tura
# Processing Record 25 of Set 3 | konstantinovka
# Processing Record 26 of Set 3 | rawson
# Processing Record 27 of Set 3 | sal rei
# Processing Record 28 of Set 3 | yialos
# City not found. Skipping...
# Processing Record 29 of Set 3 | marsa matruh
# Processing Record 30 of Set 3 | anadyr
# Processing Record 31 of Set 3 | araguatins
# City not found. Skipping...
# Processing Record 32 of Set 3 | san patricio
# Processing Record 33 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 3 | zhenjiang
# Processing Record 35 of Set 3 | dikson
# Processing Record 36 of Set 3 | jamestown
# Processing Record 37 of Set 3 | waddan
# Processing Record 38 of Set 3 | amapa
# Processing Record 39 of Set 3 | ilam
# Processing Record 40 of Set 3 | mehamn
# Processing Record 41 of Set 3 | palmas bellas
# Processing Record 42 of Set 3 | khatanga
# Processing Record 43 of Set 3 | cam ranh
# Processing Record 44 of Set 3 | maningrida
# Processing Record 45 of Set 3 | gikongoro
# Processing Record 46 of Set 3 | karratha
# Processing Record 47 of Set 3 | ponta do sol
# Processing Record 48 of Set 3 | harrisonburg
# Processing Record 49 of Set 3 | touros
# Processing Record 50 of Set 3 | ambilobe
# Processing Record 1 of Set 4 | barrow
# Processing Record 2 of Set 4 | prainha
# Processing Record 3 of Set 4 | kisangani
# Processing Record 4 of Set 4 | upernavik
# Processing Record 5 of Set 4 | ust-omchug
# Processing Record 6 of Set 4 | sandwick
# Processing Record 7 of Set 4 | nanortalik
# Processing Record 8 of Set 4 | beirut
# Processing Record 9 of Set 4 | mionica
# Processing Record 10 of Set 4 | sampit
# Processing Record 11 of Set 4 | quatre cocos
# Processing Record 12 of Set 4 | faanui
# Processing Record 13 of Set 4 | tunduru
# City not found. Skipping...
# Processing Record 14 of Set 4 | miajadas
# Processing Record 15 of Set 4 | zamania
# Processing Record 16 of Set 4 | hithadhoo
# Processing Record 17 of Set 4 | chicama
# Processing Record 18 of Set 4 | guerrero negro
# Processing Record 19 of Set 4 | hasaki
# Processing Record 20 of Set 4 | san blas
# Processing Record 21 of Set 4 | roma
# Processing Record 22 of Set 4 | provideniya
# Processing Record 23 of Set 4 | kununurra
# Processing Record 24 of Set 4 | liverpool
# Processing Record 25 of Set 4 | terrace bay
# Processing Record 26 of Set 4 | tiksi
# Processing Record 27 of Set 4 | porto novo
# Processing Record 28 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 4 | elizabeth city
# Processing Record 30 of Set 4 | santa rosa
# Processing Record 31 of Set 4 | butaritari
# Processing Record 32 of Set 4 | iwaki
# Processing Record 33 of Set 4 | thompson
# Processing Record 34 of Set 4 | port-gentil
# Processing Record 35 of Set 4 | sarkand
# Processing Record 36 of Set 4 | beaupre
# Processing Record 37 of Set 4 | korla
# Processing Record 38 of Set 4 | dzhebariki-khaya
# Processing Record 39 of Set 4 | krasnoselkup
# Processing Record 40 of Set 4 | saint george
# Processing Record 41 of Set 4 | jining
# Processing Record 42 of Set 4 | toledo
# Processing Record 43 of Set 4 | bambanglipuro
# Processing Record 44 of Set 4 | rockland
# Processing Record 45 of Set 4 | chapais
# Processing Record 46 of Set 4 | poum
# Processing Record 47 of Set 4 | pedro ii
# Processing Record 48 of Set 4 | riyadh
# Processing Record 49 of Set 4 | mackay
# Processing Record 50 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 5 | salalah
# Processing Record 2 of Set 5 | constitucion
# Processing Record 3 of Set 5 | englewood
# Processing Record 4 of Set 5 | hobyo
# Processing Record 5 of Set 5 | isangel
# Processing Record 6 of Set 5 | zhigansk
# Processing Record 7 of Set 5 | szprotawa
# Processing Record 8 of Set 5 | halifax
# Processing Record 9 of Set 5 | amalapuram
# Processing Record 10 of Set 5 | saint anthony
# Processing Record 11 of Set 5 | kabelvag
# Processing Record 12 of Set 5 | sobolevo
# Processing Record 13 of Set 5 | wahiawa
# Processing Record 14 of Set 5 | bongandanga
# Processing Record 15 of Set 5 | taltal
# Processing Record 16 of Set 5 | alta floresta
# Processing Record 17 of Set 5 | sorong
# Processing Record 18 of Set 5 | college
# Processing Record 19 of Set 5 | iskateley
# Processing Record 20 of Set 5 | geraldton
# Processing Record 21 of Set 5 | kruisfontein
# Processing Record 22 of Set 5 | kudahuvadhoo
# Processing Record 23 of Set 5 | georgetown
# Processing Record 24 of Set 5 | aklavik
# Processing Record 25 of Set 5 | kinablangan
# Processing Record 26 of Set 5 | saint-francois
# Processing Record 27 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 5 | abha
# Processing Record 29 of Set 5 | weligama
# Processing Record 30 of Set 5 | north platte
# Processing Record 31 of Set 5 | lazaro cardenas
# Processing Record 32 of Set 5 | moerai
# Processing Record 33 of Set 5 | freeport
# Processing Record 34 of Set 5 | ordynskoye
# Processing Record 35 of Set 5 | lagoa
# Processing Record 36 of Set 5 | svetlogorsk
# Processing Record 37 of Set 5 | kitimat
# Processing Record 38 of Set 5 | ahipara
# Processing Record 39 of Set 5 | zhoucun
# Processing Record 40 of Set 5 | coruripe
# Processing Record 41 of Set 5 | coahuayana
# Processing Record 42 of Set 5 | bengkulu
# Processing Record 43 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 5 | healesville
# Processing Record 45 of Set 5 | batouri
# Processing Record 46 of Set 5 | pitimbu
# Processing Record 47 of Set 5 | grand gaube
# Processing Record 48 of Set 5 | mount gambier
# Processing Record 49 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 5 | payakumbuh
# Processing Record 1 of Set 6 | havoysund
# Processing Record 2 of Set 6 | bandarbeyla
# Processing Record 3 of Set 6 | filadelfia
# Processing Record 4 of Set 6 | reconquista
# Processing Record 5 of Set 6 | galveston
# Processing Record 6 of Set 6 | solton
# Processing Record 7 of Set 6 | atar
# Processing Record 8 of Set 6 | acarau
# Processing Record 9 of Set 6 | batemans bay
# Processing Record 10 of Set 6 | charlestown
# Processing Record 11 of Set 6 | bandipur
# Processing Record 12 of Set 6 | wum
# Processing Record 13 of Set 6 | camopi
# Processing Record 14 of Set 6 | tuktoyaktuk
# Processing Record 15 of Set 6 | katsuura
# Processing Record 16 of Set 6 | tateyama
# Processing Record 17 of Set 6 | prince rupert
# Processing Record 18 of Set 6 | kasongo
# Processing Record 19 of Set 6 | muros
# Processing Record 20 of Set 6 | roseburg
# Processing Record 21 of Set 6 | funtua
# Processing Record 22 of Set 6 | sitka
# Processing Record 23 of Set 6 | warrington
# Processing Record 24 of Set 6 | mbala
# Processing Record 25 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 26 of Set 6 | grand baie
# Processing Record 27 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 28 of Set 6 | mudon
# Processing Record 29 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 6 | khandyga
# Processing Record 31 of Set 6 | ilulissat
# Processing Record 32 of Set 6 | gao
# Processing Record 33 of Set 6 | sri aman
# Processing Record 34 of Set 6 | torbay
# Processing Record 35 of Set 6 | inhambane
# Processing Record 36 of Set 6 | stornoway
# Processing Record 37 of Set 6 | luderitz
# Processing Record 38 of Set 6 | neuquen
# Processing Record 39 of Set 6 | lorengau
# Processing Record 40 of Set 6 | hualmay
# Processing Record 41 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 6 | victoria
# Processing Record 43 of Set 6 | asmar
# Processing Record 44 of Set 6 | gunjur
# Processing Record 45 of Set 6 | muchkapskiy
# Processing Record 46 of Set 6 | aksu
# Processing Record 47 of Set 6 | tamayo
# Processing Record 48 of Set 6 | los llanos de aridane
# Processing Record 49 of Set 6 | narsaq
# Processing Record 50 of Set 6 | coffeyville
# Processing Record 1 of Set 7 | ryotsu
# Processing Record 2 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 3 of Set 7 | severo-kurilsk
# Processing Record 4 of Set 7 | peniche
# Processing Record 5 of Set 7 | adrar
# Processing Record 6 of Set 7 | davila
# Processing Record 7 of Set 7 | pevek
# Processing Record 8 of Set 7 | sao joao da barra
# Processing Record 9 of Set 7 | salimpur
# Processing Record 10 of Set 7 | amarpur
# Processing Record 11 of Set 7 | nadvoitsy
# Processing Record 12 of Set 7 | kushima
# Processing Record 13 of Set 7 | beisfjord
# Processing Record 14 of Set 7 | camana
# Processing Record 15 of Set 7 | patrocinio
# Processing Record 16 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 7 | matagami
# Processing Record 18 of Set 7 | fortuna
# Processing Record 19 of Set 7 | potgietersrus
# City not found. Skipping...
# Processing Record 20 of Set 7 | porangatu
# Processing Record 21 of Set 7 | coihaique
# Processing Record 22 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 7 | kalabo
# Processing Record 24 of Set 7 | ambon
# Processing Record 25 of Set 7 | barroquinha
# Processing Record 26 of Set 7 | maragogi
# Processing Record 27 of Set 7 | fairbanks
# Processing Record 28 of Set 7 | maldonado
# Processing Record 29 of Set 7 | bogorodskoye
# Processing Record 30 of Set 7 | smidovich
# Processing Record 31 of Set 7 | harrisburg
# Processing Record 32 of Set 7 | braco do norte
# Processing Record 33 of Set 7 | longyearbyen
# Processing Record 34 of Set 7 | pacific grove
# Processing Record 35 of Set 7 | dandong
# Processing Record 36 of Set 7 | ozinki
# Processing Record 37 of Set 7 | arona
# Processing Record 38 of Set 7 | bayanday
# Processing Record 39 of Set 7 | gushi
# Processing Record 40 of Set 7 | sao sebastiao
# Processing Record 41 of Set 7 | vanderhoof
# Processing Record 42 of Set 7 | portobelo
# Processing Record 43 of Set 7 | kaa-khem
# Processing Record 44 of Set 7 | puerto escondido
# Processing Record 45 of Set 7 | namatanai
# Processing Record 46 of Set 7 | christchurch
# Processing Record 47 of Set 7 | cabo san lucas
# Processing Record 48 of Set 7 | nowy tomysl
# Processing Record 49 of Set 7 | minsk
# Processing Record 50 of Set 7 | san cosme y damian
# Processing Record 1 of Set 8 | barabai
# Processing Record 2 of Set 8 | magadan
# Processing Record 3 of Set 8 | chateauroux
# Processing Record 4 of Set 8 | tessalit
# Processing Record 5 of Set 8 | zheleznodorozhnyy
# Processing Record 6 of Set 8 | wasilla
# Processing Record 7 of Set 8 | kawana waters
# City not found. Skipping...
# Processing Record 8 of Set 8 | ndioum
# Processing Record 9 of Set 8 | bushehr
# Processing Record 10 of Set 8 | marathon
# Processing Record 11 of Set 8 | nanchang
# Processing Record 12 of Set 8 | sola
# Processing Record 13 of Set 8 | newcastle
# Processing Record 14 of Set 8 | chabahar
# Processing Record 15 of Set 8 | katobu
# Processing Record 16 of Set 8 | vestmannaeyjar
# Processing Record 17 of Set 8 | hami
# Processing Record 18 of Set 8 | ahar
# Processing Record 19 of Set 8 | gombe
# Processing Record 20 of Set 8 | samarai
# Processing Record 21 of Set 8 | pemangkat
# Processing Record 22 of Set 8 | salinopolis
# Processing Record 23 of Set 8 | luganville
# Processing Record 24 of Set 8 | deputatskiy
# Processing Record 25 of Set 8 | talnakh
# Processing Record 26 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 8 | nerchinskiy zavod
# Processing Record 28 of Set 8 | funadhoo
# Processing Record 29 of Set 8 | la asuncion
# Processing Record 30 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 31 of Set 8 | akdepe
# Processing Record 32 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 33 of Set 8 | san ramon de la nueva oran
# Processing Record 34 of Set 8 | umm lajj
# Processing Record 35 of Set 8 | wukari
# Processing Record 36 of Set 8 | tsaratanana
# Processing Record 37 of Set 8 | monterey
# Processing Record 38 of Set 8 | kodinsk
# Processing Record 39 of Set 8 | pangnirtung
# Processing Record 40 of Set 8 | banepa
# Processing Record 41 of Set 8 | lompoc
# Processing Record 42 of Set 8 | mariestad
# Processing Record 43 of Set 8 | the pas
# Processing Record 44 of Set 8 | muvattupula
# Processing Record 45 of Set 8 | opuwo
# Processing Record 46 of Set 8 | waingapu
# Processing Record 47 of Set 8 | altamira
# Processing Record 48 of Set 8 | gigmoto
# Processing Record 49 of Set 8 | marsh harbour
# Processing Record 50 of Set 8 | kamenka
# Processing Record 1 of Set 9 | waipawa
# Processing Record 2 of Set 9 | te anau
# Processing Record 3 of Set 9 | coquimbo
# Processing Record 4 of Set 9 | olinda
# Processing Record 5 of Set 9 | esil
# Processing Record 6 of Set 9 | develi
# Processing Record 7 of Set 9 | tuatapere
# Processing Record 8 of Set 9 | pointe-noire
# Processing Record 9 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 10 of Set 9 | bambous virieux
# Processing Record 11 of Set 9 | hammond
# Processing Record 12 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 9 | itaituba
# Processing Record 14 of Set 9 | slagelse
# Processing Record 15 of Set 9 | lexington park
# Processing Record 16 of Set 9 | zirandaro
# Processing Record 17 of Set 9 | okato
# Processing Record 18 of Set 9 | saldanha
# Processing Record 19 of Set 9 | grindavik
# Processing Record 20 of Set 9 | matveyevka
# Processing Record 21 of Set 9 | fomboni
# Processing Record 22 of Set 9 | mont-joli
# Processing Record 23 of Set 9 | mersing
# Processing Record 24 of Set 9 | kachikau
# City not found. Skipping...
# Processing Record 25 of Set 9 | beloha
# Processing Record 26 of Set 9 | dawlatabad
# Processing Record 27 of Set 9 | atambua
# Processing Record 28 of Set 9 | xinxiang
# Processing Record 29 of Set 9 | havre-saint-pierre
# Processing Record 30 of Set 9 | puerto madero
# Processing Record 31 of Set 9 | nuuk
# Processing Record 32 of Set 9 | andenes
# Processing Record 33 of Set 9 | mimongo
# Processing Record 34 of Set 9 | thinadhoo
# Processing Record 35 of Set 9 | buala
# Processing Record 36 of Set 9 | bara
# Processing Record 37 of Set 9 | linxia
# Processing Record 38 of Set 9 | margate
# Processing Record 39 of Set 9 | nantucket
# Processing Record 40 of Set 9 | promyshlennyy
# Processing Record 41 of Set 9 | half moon bay
# Processing Record 42 of Set 9 | auxerre
# Processing Record 43 of Set 9 | gorontalo
# Processing Record 44 of Set 9 | russell
# Processing Record 45 of Set 9 | masty
# Processing Record 46 of Set 9 | kathmandu
# Processing Record 47 of Set 9 | cabedelo
# Processing Record 48 of Set 9 | urubicha
# Processing Record 49 of Set 9 | kashi
# Processing Record 50 of Set 9 | boda
# Processing Record 1 of Set 10 | haines junction
# Processing Record 2 of Set 10 | danville
# Processing Record 3 of Set 10 | boksitogorsk
# Processing Record 4 of Set 10 | ust-ishim
# Processing Record 5 of Set 10 | mount isa
# Processing Record 6 of Set 10 | tevriz
# Processing Record 7 of Set 10 | abu samrah
# Processing Record 8 of Set 10 | kota kinabalu
# Processing Record 9 of Set 10 | borgarnes
# Processing Record 10 of Set 10 | sistranda
# Processing Record 11 of Set 10 | ferrol
# Processing Record 12 of Set 10 | vila do maio
# Processing Record 13 of Set 10 | sandakan
# Processing Record 14 of Set 10 | goderich
# Processing Record 15 of Set 10 | baboua
# City not found. Skipping...
# Processing Record 16 of Set 10 | bilma
# Processing Record 17 of Set 10 | barbate
# Processing Record 18 of Set 10 | ocampo
# Processing Record 19 of Set 10 | manjeshwar
# Processing Record 20 of Set 10 | vallenar
# Processing Record 21 of Set 10 | westport
# Processing Record 22 of Set 10 | nadym
# Processing Record 23 of Set 10 | shihezi
# Processing Record 24 of Set 10 | mizdah
# Processing Record 25 of Set 10 | henties bay
# Processing Record 26 of Set 10 | merauke
# Processing Record 27 of Set 10 | yerbogachen
# Processing Record 28 of Set 10 | yiyang
# Processing Record 29 of Set 10 | along
# Processing Record 30 of Set 10 | necochea
# Processing Record 31 of Set 10 | senanga
# Processing Record 32 of Set 10 | alofi
# Processing Record 33 of Set 10 | aykino
# Processing Record 34 of Set 10 | kawalu
# Processing Record 35 of Set 10 | port lincoln
# Processing Record 36 of Set 10 | murgab
# Processing Record 37 of Set 10 | puerto carreno
# Processing Record 38 of Set 10 | shipitsyno
# Processing Record 39 of Set 10 | nyurba
# Processing Record 40 of Set 10 | ouro fino
# Processing Record 41 of Set 10 | paliyad
# Processing Record 42 of Set 10 | palauig
# Processing Record 43 of Set 10 | sao filipe
# Processing Record 44 of Set 10 | antofagasta
# Processing Record 45 of Set 10 | littleton
# Processing Record 46 of Set 10 | kavieng
# Processing Record 47 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 10 | pachino
# Processing Record 49 of Set 10 | mumford
# Processing Record 50 of Set 10 | gat
# Processing Record 1 of Set 11 | cervo
# Processing Record 2 of Set 11 | benguela
# Processing Record 3 of Set 11 | chagoda
# Processing Record 4 of Set 11 | mushie
# Processing Record 5 of Set 11 | baoying
# Processing Record 6 of Set 11 | bousso
# Processing Record 7 of Set 11 | rio gallegos
# Processing Record 8 of Set 11 | aykhal
# Processing Record 9 of Set 11 | sharan
# Processing Record 10 of Set 11 | bima
# Processing Record 11 of Set 11 | cap malheureux
# Processing Record 12 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 11 | larsnes
# Processing Record 14 of Set 11 | koshurnikovo
# Processing Record 15 of Set 11 | alcains
# Processing Record 16 of Set 11 | florianopolis
# Processing Record 17 of Set 11 | sa kaeo
# Processing Record 18 of Set 11 | blagoyevo
# Processing Record 19 of Set 11 | zaragoza
# Processing Record 20 of Set 11 | khasan
# Processing Record 21 of Set 11 | las cruces
# Processing Record 22 of Set 11 | bairiki
# Processing Record 23 of Set 11 | comodoro rivadavia
# Processing Record 24 of Set 11 | banjar
# Processing Record 25 of Set 11 | yumen
# Processing Record 26 of Set 11 | lata
# Processing Record 27 of Set 11 | sao lourenco do sul
# Processing Record 28 of Set 11 | muriwai beach
# Processing Record 29 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 30 of Set 11 | dehloran
# Processing Record 31 of Set 11 | chkalovskoye
# Processing Record 32 of Set 11 | phalodi
# Processing Record 33 of Set 11 | acajutla
# Processing Record 34 of Set 11 | priargunsk
# Processing Record 35 of Set 11 | teloloapan
# Processing Record 36 of Set 11 | san quintin
# Processing Record 37 of Set 11 | luena
# Processing Record 38 of Set 11 | yuli
# Processing Record 39 of Set 11 | itarema
# Processing Record 40 of Set 11 | qabis
# City not found. Skipping...
# Processing Record 41 of Set 11 | ardabil
# Processing Record 42 of Set 11 | sept-iles
# Processing Record 43 of Set 11 | villa union
# Processing Record 44 of Set 11 | demyanovo
# Processing Record 45 of Set 11 | taoudenni
# Processing Record 46 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 11 | teberda
# Processing Record 48 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 11 | sidi ali
# Processing Record 50 of Set 11 | villa bruzual
# Processing Record 1 of Set 12 | fort nelson
# Processing Record 2 of Set 12 | aquiraz
# Processing Record 3 of Set 12 | dianopolis
# City not found. Skipping...
# Processing Record 4 of Set 12 | sauk rapids
# Processing Record 5 of Set 12 | payo
# Processing Record 6 of Set 12 | kutum
# Processing Record 7 of Set 12 | tecoanapa
# Processing Record 8 of Set 12 | walvis bay
# Processing Record 9 of Set 12 | pandamatenga
# Processing Record 10 of Set 12 | kirksville
# Processing Record 11 of Set 12 | poronaysk
# Processing Record 12 of Set 12 | williston
# Processing Record 13 of Set 12 | pinczow
# Processing Record 14 of Set 12 | hede
# Processing Record 15 of Set 12 | paso de carrasco
# Processing Record 16 of Set 12 | haverfordwest
# Processing Record 17 of Set 12 | kasempa
# Processing Record 18 of Set 12 | hirado
# Processing Record 19 of Set 12 | inuvik
# Processing Record 20 of Set 12 | louth
# Processing Record 21 of Set 12 | takoradi
# Processing Record 22 of Set 12 | port hardy
# Processing Record 23 of Set 12 | mahina
# Processing Record 24 of Set 12 | san vicente
# Processing Record 25 of Set 12 | posse
# Processing Record 26 of Set 12 | taraza
# Processing Record 27 of Set 12 | marzuq
# Processing Record 28 of Set 12 | aviles
# Processing Record 29 of Set 12 | iguape
# Processing Record 30 of Set 12 | bintulu
# Processing Record 31 of Set 12 | yar-sale
# Processing Record 32 of Set 12 | rundu
# Processing Record 33 of Set 12 | yinchuan
# Processing Record 34 of Set 12 | ossora
# Processing Record 35 of Set 12 | quang ngai
# Processing Record 36 of Set 12 | hamilton
# Processing Record 37 of Set 12 | itiuba
# Processing Record 38 of Set 12 | pavino
# Processing Record 39 of Set 12 | sukhobuzimskoye
# Processing Record 40 of Set 12 | wolmaranstad
# City not found. Skipping...
# Processing Record 41 of Set 12 | araguacu
# Processing Record 42 of Set 12 | mocuba
# Processing Record 43 of Set 12 | ambulu
# Processing Record 44 of Set 12 | sur
# Processing Record 45 of Set 12 | nome
# Processing Record 46 of Set 12 | merrill
# Processing Record 47 of Set 12 | palmer
# Processing Record 48 of Set 12 | kemi
# Processing Record 49 of Set 12 | basoko
# Processing Record 50 of Set 12 | shakawe
# Processing Record 1 of Set 13 | ban dung
# Processing Record 2 of Set 13 | palana
# Processing Record 3 of Set 13 | la ronge
# Processing Record 4 of Set 13 | eirunepe
# Processing Record 5 of Set 13 | asau
# Processing Record 6 of Set 13 | broken hill
# Processing Record 7 of Set 13 | san jose
# Processing Record 8 of Set 13 | nicoya
# Processing Record 9 of Set 13 | clyde river
# Processing Record 10 of Set 13 | ahuimanu
# Processing Record 11 of Set 13 | parambu
# Processing Record 12 of Set 13 | jiroft
# City not found. Skipping...
# Processing Record 13 of Set 13 | honiara
# Processing Record 14 of Set 13 | nishihara
# Processing Record 15 of Set 13 | fare
# Processing Record 16 of Set 13 | burley
# Processing Record 17 of Set 13 | yoichi
# Processing Record 18 of Set 13 | santo antonio do ica
# Processing Record 19 of Set 13 | aleppo
# Processing Record 20 of Set 13 | bowen
# Processing Record 21 of Set 13 | linkoping
# Processing Record 22 of Set 13 | orlik
# Processing Record 23 of Set 13 | kijang
# Processing Record 24 of Set 13 | kibaya
# Processing Record 25 of Set 13 | alghero
# Processing Record 26 of Set 13 | antalaha
# Processing Record 27 of Set 13 | lingao
# Processing Record 28 of Set 13 | lalibela
# Processing Record 29 of Set 13 | aranzazu
# Processing Record 30 of Set 13 | misratah
# Processing Record 31 of Set 13 | nizwa
# Processing Record 32 of Set 13 | abu dhabi
# Processing Record 33 of Set 13 | sibolga
# Processing Record 34 of Set 13 | husavik
# Processing Record 35 of Set 13 | tairua
# Processing Record 36 of Set 13 | upata
# Processing Record 37 of Set 13 | emerald
# Processing Record 38 of Set 13 | oksfjord
# Processing Record 39 of Set 13 | fukue
# Processing Record 40 of Set 13 | linkou
# Processing Record 41 of Set 13 | orel
# Processing Record 42 of Set 13 | thilogne
# City not found. Skipping...
# Processing Record 43 of Set 13 | zheshart
# Processing Record 44 of Set 13 | lamu
# Processing Record 45 of Set 13 | aksarka
# Processing Record 46 of Set 13 | asyut
# Processing Record 47 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 13 | nacala
# Processing Record 49 of Set 13 | teya
# Processing Record 50 of Set 13 | arkhangelsk
# Processing Record 1 of Set 14 | conceicao do araguaia
# Processing Record 2 of Set 14 | lekoni
# Processing Record 3 of Set 14 | shamary
# Processing Record 4 of Set 14 | novyy urengoy
# Processing Record 5 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 6 of Set 14 | kavaratti
# Processing Record 7 of Set 14 | bhongaon
# Processing Record 8 of Set 14 | beian
# Processing Record 9 of Set 14 | umba
# Processing Record 10 of Set 14 | mednogorsk
# Processing Record 11 of Set 14 | mende
# Processing Record 12 of Set 14 | srednekolymsk
# Processing Record 13 of Set 14 | lasa
# Processing Record 14 of Set 14 | sinnamary
# Processing Record 15 of Set 14 | shimoda
# Processing Record 16 of Set 14 | dhidhdhoo
# Processing Record 17 of Set 14 | maues
# Processing Record 18 of Set 14 | dunedin
# Processing Record 19 of Set 14 | kuchaman
# Processing Record 20 of Set 14 | quesnel
# Processing Record 21 of Set 14 | marawi
# Processing Record 22 of Set 14 | zharkent
# Processing Record 23 of Set 14 | willowmore
# Processing Record 24 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 14 | alice springs
# Processing Record 26 of Set 14 | riviere-du-loup
# Processing Record 27 of Set 14 | yenagoa
# Processing Record 28 of Set 14 | maykain
# City not found. Skipping...
# Processing Record 29 of Set 14 | achisay
# City not found. Skipping...
# Processing Record 30 of Set 14 | kysyl-syr
# Processing Record 31 of Set 14 | ekibastuz
# Processing Record 32 of Set 14 | ziro
# Processing Record 33 of Set 14 | sergeyevka
# Processing Record 34 of Set 14 | mandiana
# Processing Record 35 of Set 14 | zhezkazgan
# Processing Record 36 of Set 14 | east london
# Processing Record 37 of Set 14 | carmelo
# Processing Record 38 of Set 14 | tashtyp
# Processing Record 39 of Set 14 | koumac
# Processing Record 40 of Set 14 | bilopillya
# Processing Record 41 of Set 14 | bayji
# Processing Record 42 of Set 14 | robertsport
# Processing Record 43 of Set 14 | roebourne
# Processing Record 44 of Set 14 | nemuro
# Processing Record 45 of Set 14 | acapulco
# Processing Record 46 of Set 14 | denia
# Processing Record 47 of Set 14 | panaba
# Processing Record 48 of Set 14 | leshukonskoye
# Processing Record 49 of Set 14 | trelew
# Processing Record 50 of Set 14 | gananoque
# Processing Record 1 of Set 15 | galesong
# Processing Record 2 of Set 15 | cape canaveral
# Processing Record 3 of Set 15 | camalu
# Processing Record 4 of Set 15 | griffith
# Processing Record 5 of Set 15 | astana
# Processing Record 6 of Set 15 | tromso
# Processing Record 7 of Set 15 | lokosovo
# Processing Record 8 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 15 | ola
# Processing Record 10 of Set 15 | qeshm
# Processing Record 11 of Set 15 | rovaniemi
# Processing Record 12 of Set 15 | tiruppuvanam
# Processing Record 13 of Set 15 | mogadishu
# Processing Record 14 of Set 15 | guia de isora
# Processing Record 15 of Set 15 | namibe
# Processing Record 16 of Set 15 | careiro da varzea
# Processing Record 17 of Set 15 | mlimba
# Processing Record 18 of Set 15 | durazno
# Processing Record 19 of Set 15 | san policarpo
# Processing Record 20 of Set 15 | dakoro
# Processing Record 21 of Set 15 | kattivakkam
# Processing Record 22 of Set 15 | puerto leguizamo
# Processing Record 23 of Set 15 | kozhva
# Processing Record 24 of Set 15 | vao
# Processing Record 25 of Set 15 | qaqortoq
# Processing Record 26 of Set 15 | korem
# Processing Record 27 of Set 15 | puro
# Processing Record 28 of Set 15 | xining
# Processing Record 29 of Set 15 | thai binh
# Processing Record 30 of Set 15 | maymyo
# Processing Record 31 of Set 15 | sambava
# Processing Record 32 of Set 15 | matamoros
# Processing Record 33 of Set 15 | kenai
# Processing Record 34 of Set 15 | san carlos de bariloche
# Processing Record 35 of Set 15 | adet
# Processing Record 36 of Set 15 | big bend
# Processing Record 37 of Set 15 | sabalgarh
# Processing Record 38 of Set 15 | karpogory
# Processing Record 39 of Set 15 | kiunga
# Processing Record 40 of Set 15 | tambilil
# Processing Record 41 of Set 15 | paralia
# Processing Record 42 of Set 15 | takhtamygda
# Processing Record 43 of Set 15 | brae
# Processing Record 44 of Set 15 | seoni
# Processing Record 45 of Set 15 | kindia
# Processing Record 46 of Set 15 | san cristobal
# Processing Record 47 of Set 15 | kaspiyskiy
# Processing Record 48 of Set 15 | tarakan
# Processing Record 49 of Set 15 | jablanica
# Processing Record 50 of Set 15 | mabaruma
# Processing Record 1 of Set 16 | vestmanna
# Processing Record 2 of Set 16 | gushikawa
# Processing Record 3 of Set 16 | barisal
# Processing Record 4 of Set 16 | juneau
# Processing Record 5 of Set 16 | ciupercenii noi
# Processing Record 6 of Set 16 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 16 | narrabri
# Processing Record 8 of Set 16 | tari
# Processing Record 9 of Set 16 | ukiah
# Processing Record 10 of Set 16 | chapada dos guimaraes
# Processing Record 11 of Set 16 | punta alta
# Processing Record 12 of Set 16 | karlshamn
# Processing Record 13 of Set 16 | uvira
# Processing Record 14 of Set 16 | luanda
# Processing Record 15 of Set 16 | vostok
# Processing Record 16 of Set 16 | general roca
# Processing Record 17 of Set 16 | tuy hoa
# Processing Record 18 of Set 16 | burgeo
# Processing Record 19 of Set 16 | itabaiana
# Processing Record 20 of Set 16 | bella union
# Processing Record 21 of Set 16 | chissamba
# Processing Record 22 of Set 16 | emborion
# Processing Record 23 of Set 16 | labutta
# City not found. Skipping...
# Processing Record 24 of Set 16 | warmbad
# Processing Record 25 of Set 16 | karaul
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
WeatherPy_Database = pd.DataFrame(city_data)
WeatherPy_Database.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Cherskiy  68.75  161.30     38.21        93         100       11.56
# 1       Busselton -33.65  115.33     42.01        82           0        3.83
# 2      Bredasdorp -34.53   20.04     57.20        87         100        2.24
# 3            Lebu -37.62  -73.65     51.13        91         100       18.70
# 4           Kapaa  22.08 -159.32     84.20        70          20       10.29
# 5       Carnarvon -24.87  113.63     60.80        82           0       10.29
# 6         Qaanaaq  77.48  -69.36     36.79        87         100        5.12
# 7            Auki  -8.77  160.70     79.34        83          65        3.62
# 8  Ribeira Grande  38.52  -28.70     75.20        88          40        8.05
# 9      Lavrentiya  65.58 -171.00     47.21        93         100        4.99
#
#   Country Current Description
# 0      RU          light rain
# 1      AU           clear sky
# 2      ZA     overcast clouds
# 3      CL          light rain
# 4      US          few clouds
# 5      AU           clear sky
# 6      GL     overcast clouds
# 7      SB       broken clouds
# 8      PT    scattered clouds
# 9      RU     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
WeatherPy_Database = WeatherPy_Database[new_column_order]
WeatherPy_Database.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Cherskiy      RU  68.75  161.30     38.21        93         100
# 1       Busselton      AU -33.65  115.33     42.01        82           0
# 2      Bredasdorp      ZA -34.53   20.04     57.20        87         100
# 3            Lebu      CL -37.62  -73.65     51.13        91         100
# 4           Kapaa      US  22.08 -159.32     84.20        70          20
# 5       Carnarvon      AU -24.87  113.63     60.80        82           0
# 6         Qaanaaq      GL  77.48  -69.36     36.79        87         100
# 7            Auki      SB  -8.77  160.70     79.34        83          65
# 8  Ribeira Grande      PT  38.52  -28.70     75.20        88          40
# 9      Lavrentiya      RU  65.58 -171.00     47.21        93         100
#
#    Wind Speed Current Description
# 0       11.56          light rain
# 1        3.83           clear sky
# 2        2.24     overcast clouds
# 3       18.70          light rain
# 4       10.29          few clouds
# 5       10.29           clear sky
# 6        5.12     overcast clouds
# 7        3.62       broken clouds
# 8        8.05    scattered clouds
# 9        4.99     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
WeatherPy_Database.to_csv(output_data_file, index_label="City_ID")
